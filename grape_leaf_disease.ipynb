# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'D:\Main project\fruitLeafDisease\project 4-2\CB1004 - AUTOMATIC FRUIT DISEASE DETECTION BY IMAGE ON CLOUD COMPUTING\SOURCE CODE\dataset\grape_features.csv')
df
# Out:
#       Unnamed: 0     area    perimeter  physiological_length  \
# 0              0      0.0     0.000000                     0
# 1              0    204.0   133.455844                    27
# 2              0      0.0    10.000000                     5
# 3              0      0.0     0.000000                     0
# 4              0      0.0     0.000000                     0
# ...          ...      ...          ...                   ...
# 4084           0      0.0    28.970562                    18
# 4085           0      0.0     0.000000                     0
# 4086           0     36.0   122.911687                    54
# 4087           0  20685.0  6500.321179                  1344
# 4088           0      0.0     0.000000                     0
#
#       physiological_width  aspect_ratio  rectangularity   circularity  \
# 0                       0      0.000000        0.000000      0.000000
# 1                      51      1.588235        4.125000    174.612375
# ...

# %%
y=df['class']
y
# Out:
# 0                                Black_rot
# 1                                Black_rot
# 2                                Black_rot
# 3                                Black_rot
# 4                                Black_rot
#                        ...
# 4084    Leaf_blight_(Isariopsis_Leaf_Spot)
# 4085    Leaf_blight_(Isariopsis_Leaf_Spot)
# 4086    Leaf_blight_(Isariopsis_Leaf_Spot)
# 4087    Leaf_blight_(Isariopsis_Leaf_Spot)
# 4088    Leaf_blight_(Isariopsis_Leaf_Spot)
# Name: class, Length: 4089, dtype: object

# %%
x=df.drop(['class'], axis='columns')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,z,test_size=0.2,random_state=10)

# %%
x_train
# Out:
#       Unnamed: 0  area   perimeter  physiological_length  physiological_width  \
# 3237           0   0.0    0.000000                    16                   16
# 194            0  50.0  164.852812                    60                   60
# 1284           0   0.0    0.000000                     0                    0
# 764            0   0.0    0.000000                     0                    0
# 2748           0   4.0   17.656854                     6                    8
# ...          ...   ...         ...                   ...                  ...
# 1344           0   0.0    0.000000                     0                    0
# 527            0  78.0   70.970562                    18                   27
# 4068           0   0.0    0.000000                     0                    0
# 3197           0   0.0    0.000000                     0                    0
# 1289           0   0.0   12.000000                     2                    8
#
# ...

# %%
x_test
# Out:
#       Unnamed: 0   area   perimeter  physiological_length  \
# 349            0    0.0    0.000000                     0
# 1243           0    0.0   32.000000                     4
# 616            0    0.0    0.000000                     0
# 3246           0    0.0    0.000000                    10
# 3873           0  180.0  216.568542                    48
# ...          ...    ...         ...                   ...
# 2876           0    0.0    0.000000                     0
# 1641           0  330.0  612.852812                   144
# 1235           0    0.5    5.414214                     3
# 1126           0   96.5   49.899495                     7
# 2237           0  144.0  104.284271                    20
#
#       physiological_width  aspect_ratio  rectangularity  circularity  \
# 349                     0      0.000000        0.000000     0.000000
# 1243                   20      0.800000        0.000000     0.000000
# ...

# %%
y_train
# Out:
# 3237    Leaf_blight_(Isariopsis_Leaf_Spot)
# 194                              Black_rot
# 1284                             Black_rot
# 764     Leaf_blight_(Isariopsis_Leaf_Spot)
# 2748                  Esca_(Black_Measles)
#                        ...
# 1344                             Black_rot
# 527                                Healthy
# 4068    Leaf_blight_(Isariopsis_Leaf_Spot)
# 3197                               Healthy
# 1289                             Black_rot
# Name: class, Length: 3271, dtype: object

# %%
y_test
# Out:
# 349                   Esca_(Black_Measles)
# 1243                             Black_rot
# 616                                Healthy
# 3246    Leaf_blight_(Isariopsis_Leaf_Spot)
# 3873    Leaf_blight_(Isariopsis_Leaf_Spot)
#                        ...
# 2876                  Esca_(Black_Measles)
# 1641                             Black_rot
# 1235                             Black_rot
# 1126                             Black_rot
# 2237                  Esca_(Black_Measles)
# Name: class, Length: 818, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
logi=LogisticRegression()

# %%
logi.fit(x_train,y_train)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logi.predict(x_test)
# Out:
# array(['Esca_(Black_Measles)', 'Esca_(Black_Measles)', 'Black_rot',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Black_rot', 'Black_rot', 'Black_rot',
#        'Black_rot', 'Black_rot', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Esca_(Black_Measles)', 'Black_rot', 'Esca_(Black_Measles)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Esca_(Black_Measles)',
# ...

# %%
a=logi.score(x_test,y_test)
a
# Out:
# 0.5953545232273839

# %%
from sklearn.tree import DecisionTreeClassifier
deci=DecisionTreeClassifier()
deci.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
deci.predict(x_test)
# Out:
# array(['Esca_(Black_Measles)', 'Black_rot', 'Healthy',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Black_rot', 'Black_rot',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)', 'Black_rot',
#        'Black_rot', 'Esca_(Black_Measles)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Black_rot', 'Black_rot', 'Black_rot',
#        'Healthy', 'Black_rot', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot', 'Black_rot',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Healthy', 'Healthy', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Esca_(Black_Measles)', 'Black_rot', 'Healthy',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot',
# ...

# %%
b=deci.score(x_test,y_test)
b
# Out:
# 0.7481662591687042

# %%
from sklearn.ensemble import RandomForestClassifier
ran=RandomForestClassifier()
ran.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred=ran.predict(x_test)
pred
# Out:
# array(['Esca_(Black_Measles)', 'Esca_(Black_Measles)', 'Healthy',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Black_rot', 'Esca_(Black_Measles)',
#        'Black_rot', 'Esca_(Black_Measles)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Healthy', 'Esca_(Black_Measles)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)', 'Black_rot',
#        'Black_rot', 'Black_rot', 'Healthy', 'Black_rot',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot', 'Black_rot',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Healthy', 'Healthy', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Black_rot', 'Esca_(Black_Measles)', 'Healthy',
# ...

# %%
c=ran.score(x_test,y_test)
c
# Out:
# 0.8215158924205379

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
sv.predict(x_test)
# Out:
# array(['Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Black_rot', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Esca_(Black_Measles)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Esca_(Black_Measles)', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)',
# ...

# %%
d=sv.score(x_test,y_test)
d
# Out:
# 0.4119804400977995

# %%
from sklearn.ensemble import BaggingClassifier
bag=BaggingClassifier()

# %%
bag.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
bag.predict(x_test)
# Out:
# array(['Black_rot', 'Black_rot', 'Healthy',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Black_rot', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Black_rot', 'Esca_(Black_Measles)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Esca_(Black_Measles)',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)', 'Black_rot',
#        'Black_rot', 'Black_rot', 'Healthy', 'Black_rot',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot', 'Black_rot',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Healthy', 'Healthy', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Black_rot', 'Esca_(Black_Measles)', 'Healthy',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot',
# ...

# %%
e=bag.score(x_test,y_test)
e
# Out:
# 0.7970660146699267

# %%
from sklearn.ensemble import AdaBoostClassifier
ad=AdaBoostClassifier()

# %%
ad.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
ad.predict(x_test)
# Out:
# array(['Black_rot', 'Esca_(Black_Measles)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Black_rot', 'Black_rot',
#        'Esca_(Black_Measles)', 'Esca_(Black_Measles)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Black_rot', 'Black_rot',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot', 'Black_rot',
#        'Black_rot', 'Esca_(Black_Measles)', 'Black_rot', 'Healthy',
#        'Black_rot', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot', 'Black_rot',
#        'Leaf_blight_(Isariopsis_Leaf_Spot)', 'Black_rot',
#        'Esca_(Black_Measles)', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Black_rot', 'Healthy', 'Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Black_rot', 'Esca_(Black_Measles)', 'Healthy',
# ...

# %%
f=ad.score(x_test,y_test)
f
# Out:
# 0.7493887530562348

# %%
x2=['logistic reg','decitree','randforest','svc','bagging','adaboost']

# %%
y2=[a,b,c,d,e,f]
y2
# Out:
# [0.5953545232273839,
#  0.7481662591687042,
#  0.8215158924205379,
#  0.4119804400977995,
#  0.7970660146699267,
#  0.7493887530562348]

# %%
plt.xlabel('models')
plt.ylabel('accuracy')
plt.title('model training')
plt.bar(x2,y2)
# Out:
# <BarContainer object of 6 artists>
